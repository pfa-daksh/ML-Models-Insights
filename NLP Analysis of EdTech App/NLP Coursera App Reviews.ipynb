# %%
import spacy
import pandas as pd
from spacy.lang.en import English
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
file = open(r"C:\Users\nisha\OneDrive\Documents\python\\coursera.csv", "r+", encoding='utf-8')

# %%
string = ""
for x in file:
    string += x
print(string)
str1 = string.lower()
print(str1)
# Out:
# content
# A battery drainer. 7% while app wasn't even opened. And please add a possibility to view videos at a higher speed. Thanks
# A believe z gonna make sense
# "A bit laggy for me, but it's content is worth it."
# A boon to our generation!
# A boost to your self awareness and a mind refresher. Lovely
# A brilliant thought provoking course I am enriched with the knowledge.
# a career booster indeed
# A chance to refresh my knowledge
# "A couple issues with rotations & video playback and loading saved videos when not having Internet connectivity (subway), but IMHO these are minor issues. Psyched to see that Coursera values its Android user base with a great app. Props to the engineering team--an excellent experience and fantastic execution!!!"
# "a couple of minor tweaks would make it prefect, still 5 star though compared to a lot of other apps"
# A fairly useless and redundant  app with out Chromecast support.
# ...

# %%
list_sent = sent_tokenize(str1)
print(list_sent)
# Out:
# ['content\na battery drainer.', "7% while app wasn't even opened.", 'and please add a possibility to view videos at a higher speed.', 'thanks\na believe z gonna make sense\n"a bit laggy for me, but it\'s content is worth it."', 'a boon to our generation!', 'a boost to your self awareness and a mind refresher.', 'lovely\na brilliant thought provoking course i am enriched with the knowledge.', 'a career booster indeed\na chance to refresh my knowledge\n"a couple issues with rotations & video playback and loading saved videos when not having internet connectivity (subway), but imho these are minor issues.', 'psyched to see that coursera values its android user base with a great app.', 'props to the engineering team--an excellent experience and fantastic execution!!!"', '"a couple of minor tweaks would make it prefect, still 5 star though compared to a lot of other apps"\na fairly useless and redundant  app with out chromecast support.', 'a feature to download lectures to external sd car
# ...

# %%
list_word = word_tokenize(str1)
print(list_word)
# Out:
# ['content', 'a', 'battery', 'drainer', '.', '7', '%', 'while', 'app', 'was', "n't", 'even', 'opened', '.', 'and', 'please', 'add', 'a', 'possibility', 'to', 'view', 'videos', 'at', 'a', 'higher', 'speed', '.', 'thanks', 'a', 'believe', 'z', 'gon', 'na', 'make', 'sense', "''", 'a', 'bit', 'laggy', 'for', 'me', ',', 'but', 'it', "'s", 'content', 'is', 'worth', 'it', '.', "''", 'a', 'boon', 'to', 'our', 'generation', '!', 'a', 'boost', 'to', 'your', 'self', 'awareness', 'and', 'a', 'mind', 'refresher', '.', 'lovely', 'a', 'brilliant', 'thought', 'provoking', 'course', 'i', 'am', 'enriched', 'with', 'the', 'knowledge', '.', 'a', 'career', 'booster', 'indeed', 'a', 'chance', 'to', 'refresh', 'my', 'knowledge', "''", 'a', 'couple', 'issues', 'with', 'rotations', '&', 'video', 'playback', 'and', 'loading', 'saved', 'videos', 'when', 'not', 'having', 'internet', 'connectivity', '(', 'subway', ')', ',', 'but', 'imho', 'these', 'are', 'minor', 'issues', '.', 'psyched', 'to', 'see', 'that', 'co
# ...

# %%
len(set(str1)) # Number of unique words in the reviews
# Out:
# 137

# %%
str1.count("learn")
# Out:
# 389

# %%
str1.count("best")
# Out:
# 102

# %%
str1.count("course")
# Out:
# 845

# %%
str1.count("amazing")
# Out:
# 238

# %%
str1.count("great")
# Out:
# 377

# %%
from nltk.corpus import stopwords
stopword = stopwords.words("english") # Importing the list of stop words from nltk

# %%
stopwords_removed = [word for word in list_word if word not in stopword]
print(stopwords_removed) # Removing the stop words from tokenized words from the reviews
# Out:
# ['content', 'battery', 'drainer', '.', '7', '%', 'app', "n't", 'even', 'opened', '.', 'please', 'add', 'possibility', 'view', 'videos', 'higher', 'speed', '.', 'thanks', 'believe', 'z', 'gon', 'na', 'make', 'sense', "''", 'bit', 'laggy', ',', "'s", 'content', 'worth', '.', "''", 'boon', 'generation', '!', 'boost', 'self', 'awareness', 'mind', 'refresher', '.', 'lovely', 'brilliant', 'thought', 'provoking', 'course', 'enriched', 'knowledge', '.', 'career', 'booster', 'indeed', 'chance', 'refresh', 'knowledge', "''", 'couple', 'issues', 'rotations', '&', 'video', 'playback', 'loading', 'saved', 'videos', 'internet', 'connectivity', '(', 'subway', ')', ',', 'imho', 'minor', 'issues', '.', 'psyched', 'see', 'coursera', 'values', 'android', 'user', 'base', 'great', 'app', '.', 'props', 'engineering', 'team', '--', 'excellent', 'experience', 'fantastic', 'execution', '!', '!', '!', "''", '``', 'couple', 'minor', 'tweaks', 'would', 'make', 'prefect', ',', 'still', '5', 'star', 'though', 'co
# ...

# %%
# Removing stopwords from the list of tokenized sentences from the reviews
import gensim
from gensim.parsing.preprocessing import remove_stopwords
list_sent2 = ""
for sentence in list_sent:
    list_sent2 += remove_stopwords(sentence)

# %%
list_sent3 = sent_tokenize(list_sent2)# Now we have sentences with stop words removed
print(list_sent3)
# Out:
# ['content battery drainer.7% app wasn\'t opened.add possibility view videos higher speed.thanks believe z gonna sense "a bit laggy me, it\'s content worth it.', '"boon generation!boost self awareness mind refresher.lovely brilliant thought provoking course enriched knowledge.career booster chance refresh knowledge "a couple issues rotations & video playback loading saved videos having internet connectivity (subway), imho minor issues.psyched coursera values android user base great app.props engineering team--an excellent experience fantastic execution!!!', '""a couple minor tweaks prefect, 5 star compared lot apps" fairly useless redundant app chromecast support.feature download lectures external sd card useful filter added free paid courses "add dark theme, please" add way download assignments add ability change video speed & solve video quizzes add explanation permission.need it.it\'s fair transparent users.add bookmark feature wanted coursera app!alwys grt testing it.....wish luck
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()
str4 = ""
for x in range(len(stopwords_removed)):
    stopwords_removed[x] = lemma.lemmatize(stopwords_removed[x])

print(stopwords_removed)# Now we have lemmatized word from the reviews with stop words removed.
# Out:
# ['content', 'battery', 'drainer', '.', '7', '%', 'app', "n't", 'even', 'opened', '.', 'please', 'add', 'possibility', 'view', 'video', 'higher', 'speed', '.', 'thanks', 'believe', 'z', 'gon', 'na', 'make', 'sense', "''", 'bit', 'laggy', ',', "'s", 'content', 'worth', '.', "''", 'boon', 'generation', '!', 'boost', 'self', 'awareness', 'mind', 'refresher', '.', 'lovely', 'brilliant', 'thought', 'provoking', 'course', 'enriched', 'knowledge', '.', 'career', 'booster', 'indeed', 'chance', 'refresh', 'knowledge', "''", 'couple', 'issue', 'rotation', '&', 'video', 'playback', 'loading', 'saved', 'video', 'internet', 'connectivity', '(', 'subway', ')', ',', 'imho', 'minor', 'issue', '.', 'psyched', 'see', 'coursera', 'value', 'android', 'user', 'base', 'great', 'app', '.', 'prop', 'engineering', 'team', '--', 'excellent', 'experience', 'fantastic', 'execution', '!', '!', '!', "''", '``', 'couple', 'minor', 'tweak', 'would', 'make', 'prefect', ',', 'still', '5', 'star', 'though', 'compared',
# ...

# %%
from nltk import pos_tag
tagged_wrds = pos_tag(stopwords_removed)
print(tagged_wrds)
# Out:
# [('content', 'JJ'), ('battery', 'NN'), ('drainer', 'NN'), ('.', '.'), ('7', 'CD'), ('%', 'NN'), ('app', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('opened', 'VBN'), ('.', '.'), ('please', 'VB'), ('add', 'JJ'), ('possibility', 'NN'), ('view', 'NN'), ('video', 'NN'), ('higher', 'JJR'), ('speed', 'NN'), ('.', '.'), ('thanks', 'NNS'), ('believe', 'VBP'), ('z', 'NN'), ('gon', 'NN'), ('na', 'TO'), ('make', 'VB'), ('sense', 'NN'), ("''", "''"), ('bit', 'NN'), ('laggy', 'JJ'), (',', ','), ("'s", 'POS'), ('content', 'JJ'), ('worth', 'NN'), ('.', '.'), ("''", "''"), ('boon', 'NN'), ('generation', 'NN'), ('!', '.'), ('boost', 'NN'), ('self', 'NN'), ('awareness', 'NN'), ('mind', 'NN'), ('refresher', 'NN'), ('.', '.'), ('lovely', 'RB'), ('brilliant', 'JJ'), ('thought', 'VBD'), ('provoking', 'VBG'), ('course', 'NN'), ('enriched', 'VBD'), ('knowledge', 'NN'), ('.', '.'), ('career', 'NN'), ('booster', 'NN'), ('indeed', 'RB'), ('chance', 'NN'), ('refresh', 'NN'), ('knowledge', 'NN'), ("''", "''"), ('cou
# ...

# %%
import textblob
from textblob import TextBlob

# %%
for sentence in list_sent: # Sentiment of each tweet using TextBlob.
    
    print(TextBlob(sentence).sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.5)
# Sentiment(polarity=0.25, subjectivity=0.15000000000000002)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.875)
# Sentiment(polarity=-0.05, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.875)
# Sentiment(polarity=0.890625, subjectivity=0.95)
# Sentiment(polarity=-0.21875, subjectivity=0.24374999999999997)
# Sentiment(polarity=0.16, subjectivity=0.325)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4904761904761905, subjectivity=0.7047619047619048)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.25)
# Sentiment(polarity=0.4, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...

# %%
print(TextBlob(str1).sentiment) # Sentiment of all the reviews together
# Out:
# Sentiment(polarity=0.33702949190994275, subjectivity=0.5796231138294089)

# %%
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
for sentence in list_sent:
    print(analyzer.polarity_scores(sentence))
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
# {'neg': 0.098, 'neu': 0.489, 'pos': 0.413, 'compound': 0.7783}
# {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.34}
# {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'compound': 0.7783}
# {'neg': 0.0, 'neu': 0.495, 'pos': 0.505, 'compound': 0.8472}
# {'neg': 0.084, 'neu': 0.836, 'pos': 0.081, 'compound': -0.0258}
# {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.8977}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.033, 'neu': 0.769, 'pos': 0.198, 'compound': 0.9639}
# ...

# %%
print(analyzer.polarity_scores(str1))
# Out:
# {'neg': 0.063, 'neu': 0.645, 'pos': 0.292, 'compound': 1.0}

# %%
NLP = spacy.load('en_core_web_sm')
doc = NLP(str1)

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# 7% 27 29 PERCENT
# android 620 627 ORG
# 5 794 795 CARDINAL
# samsung 2119 2126 ORG
# 4 2131 2132 DATE
# veronica stephen 2278 2294 PERSON
# nigeria 2328 2335 GPE
# ☺ 3010 3011 ORG
# 😶 3857 3858 ORG
# 👌 3924 3925 PRODUCT
# yale 4442 4446 ORG
# almost a month 4732 4746 DATE
# cousera
# amazing 5399 5414 PERSON
# 1.75x 5926 5931 CARDINAL
# andrew ng
#  5967 5977 PERSON
# some days 7042 7051 DATE
# one 7127 7130 CARDINAL
# 👌 7302 7303 PRODUCT
# one 7799 7802 CARDINAL
# one 10390 10393 CARDINAL
# seven 10401 10406 CARDINAL
# the past decade 10443 10458 DATE
# barbara oakley 10767 10781 PERSON
# android 12344 12351 ORG
# one 12697 12700 CARDINAL
# recent years 12900 12912 DATE
# each week 13144 13153 DATE
# android 13936 13943 ORG
# 2.3 13944 13947 CARDINAL
# android 14189 14196 PERSON
# 6.0 14206 14209 CARDINAL
# freezes.i 14307 14316 ORG
# 😪 14468 14469 WORK_OF_ART
# 20 dayum days 14692 14705 DATE
# today 14826 14831 DATE
# 3 14866 14867 CARDINAL
# week 2 14909 14915 DATE
# ...
